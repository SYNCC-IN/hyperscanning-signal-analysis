# %%
import os
import sys
import xarray as xr
import importlib
from pathlib import Path
sys.path.insert(0, os.path.abspath('..'))

import src.mtmvar
import src.export
import src.ica_preprocessing
importlib.reload(src.mtmvar)
importlib.reload(src.export)
importlib.reload(src.ica_preprocessing)

from src.export import plot_loaded_eeg_signals
from src.ica_preprocessing import ICAPreprocessor

# %%
export_folder = Path(r"C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_raw")
cleaned_signals_folder = Path(r"C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG")
target_events = ['Brave', 'Peppa', 'Incredibles']
ICAP = ICAPreprocessor(export_folder, target_events)

# %%
ICAP.find_eeg_files(smoke_test=True, smoke_dyads_n=3)
# Out:
# Mode: SMOKE TEST (first 3 dyads)
# Dyads selected: 3 / 60
# Files selected: 18 / 346
# Dyads:
#   - W_000
#   - W_001
#   - W_002

# %%
ICAP.preprocess_and_save(cleaned_signals_folder, save_plots=True)
# Out:
# ## W_000_EEG_cg_Brave
# Processing & Saving: W_000_EEG_cg_Brave.nc
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 21 PCA components
# -> Saved NetCDF to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_000\W_000_EEG_cg_Brave_cleaned.nc
# Saved plot preview to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_000\W_000_EEG_cg_Brave_cleaned_ica_plot.png
# ## W_000_EEG_cg_Incredibles
# Processing & Saving: W_000_EEG_cg_Incredibles.nc
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 21 PCA components
# -> Saved NetCDF to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_000\W_000_EEG_cg_Incredibles_cleaned.nc
# Saved plot preview to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_000\W_000_EEG_cg_Incredibles_cleaned_ica_plot.png
# ## W_000_EEG_cg_Peppa
# Processing & Saving: W_000_EEG_cg_Peppa.nc
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 21 PCA components
# -> Saved NetCDF to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_000\W_000_EEG_cg_Peppa_cleaned.nc
# Saved plot preview to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_000\W_000_EEG_cg_Peppa_cleaned_ica_plot.png
# ## W_000_EEG_ch_Brave
# Processing & Saving: W_000_EEG_ch_Brave.nc
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 21 PCA components
# -> Saved NetCDF to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_000\W_000_EEG_ch_Brave_cleaned.nc
# Saved plot preview to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_000\W_000_EEG_ch_Brave_cleaned_ica_plot.png
# ## W_000_EEG_ch_Incredibles
# Processing & Saving: W_000_EEG_ch_Incredibles.nc
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 21 PCA components
# -> Saved NetCDF to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_000\W_000_EEG_ch_Incredibles_cleaned.nc
# Saved plot preview to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_000\W_000_EEG_ch_Incredibles_cleaned_ica_plot.png
# ## W_000_EEG_ch_Peppa
# Processing & Saving: W_000_EEG_ch_Peppa.nc
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 21 PCA components
# -> Saved NetCDF to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_000\W_000_EEG_ch_Peppa_cleaned.nc
# Saved plot preview to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_000\W_000_EEG_ch_Peppa_cleaned_ica_plot.png
# ## W_001_EEG_cg_Brave
# Processing & Saving: W_001_EEG_cg_Brave.nc
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 21 PCA components
# -> Saved NetCDF to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_001\W_001_EEG_cg_Brave_cleaned.nc
# Saved plot preview to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_001\W_001_EEG_cg_Brave_cleaned_ica_plot.png
# ## W_001_EEG_cg_Incredibles
# Processing & Saving: W_001_EEG_cg_Incredibles.nc
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 21 PCA components
# -> Saved NetCDF to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_001\W_001_EEG_cg_Incredibles_cleaned.nc
# Saved plot preview to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_001\W_001_EEG_cg_Incredibles_cleaned_ica_plot.png
# ## W_001_EEG_cg_Peppa
# Processing & Saving: W_001_EEG_cg_Peppa.nc
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 21 PCA components
# -> Saved NetCDF to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_001\W_001_EEG_cg_Peppa_cleaned.nc
# Saved plot preview to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_001\W_001_EEG_cg_Peppa_cleaned_ica_plot.png
# ## W_001_EEG_ch_Brave
# Processing & Saving: W_001_EEG_ch_Brave.nc
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 21 PCA components
# -> Saved NetCDF to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_001\W_001_EEG_ch_Brave_cleaned.nc
# Saved plot preview to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_001\W_001_EEG_ch_Brave_cleaned_ica_plot.png
# ## W_001_EEG_ch_Incredibles
# Processing & Saving: W_001_EEG_ch_Incredibles.nc
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 21 PCA components
# -> Saved NetCDF to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_001\W_001_EEG_ch_Incredibles_cleaned.nc
# Saved plot preview to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_001\W_001_EEG_ch_Incredibles_cleaned_ica_plot.png
# ## W_001_EEG_ch_Peppa
# Processing & Saving: W_001_EEG_ch_Peppa.nc
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
# c:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\venv\Lib\site-packages\sklearn\decomposition\_fastica.py:132: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 0 ICA components
#     Projecting back using 21 PCA components
# -> Saved NetCDF to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_001\W_001_EEG_ch_Peppa_cleaned.nc
# Saved plot preview to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_001\W_001_EEG_ch_Peppa_cleaned_ica_plot.png
# ## W_002_EEG_cg_Brave
# Processing & Saving: W_002_EEG_cg_Brave.nc
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 21 PCA components
# -> Saved NetCDF to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_002\W_002_EEG_cg_Brave_cleaned.nc
# Saved plot preview to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_002\W_002_EEG_cg_Brave_cleaned_ica_plot.png
# ## W_002_EEG_cg_Incredibles
# Processing & Saving: W_002_EEG_cg_Incredibles.nc
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 21 PCA components
# -> Saved NetCDF to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_002\W_002_EEG_cg_Incredibles_cleaned.nc
# Saved plot preview to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_002\W_002_EEG_cg_Incredibles_cleaned_ica_plot.png
# ## W_002_EEG_cg_Peppa
# Processing & Saving: W_002_EEG_cg_Peppa.nc
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 21 PCA components
# -> Saved NetCDF to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_002\W_002_EEG_cg_Peppa_cleaned.nc
# Saved plot preview to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_002\W_002_EEG_cg_Peppa_cleaned_ica_plot.png
# ## W_002_EEG_ch_Brave
# Processing & Saving: W_002_EEG_ch_Brave.nc
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 21 PCA components
# -> Saved NetCDF to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_002\W_002_EEG_ch_Brave_cleaned.nc
# Saved plot preview to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_002\W_002_EEG_ch_Brave_cleaned_ica_plot.png
# ## W_002_EEG_ch_Incredibles
# Processing & Saving: W_002_EEG_ch_Incredibles.nc
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
# c:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\venv\Lib\site-packages\sklearn\decomposition\_fastica.py:132: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 21 PCA components
# -> Saved NetCDF to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_002\W_002_EEG_ch_Incredibles_cleaned.nc
# Saved plot preview to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_002\W_002_EEG_ch_Incredibles_cleaned_ica_plot.png
# ## W_002_EEG_ch_Peppa
# Processing & Saving: W_002_EEG_ch_Peppa.nc
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# c:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\venv\Lib\site-packages\sklearn\decomposition\_fastica.py:132: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# - Filter length: 1280 samples (10.000 s)
#
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 21 PCA components
# -> Saved NetCDF to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_002\W_002_EEG_ch_Peppa_cleaned.nc
# Saved plot preview to: C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\DATA_film_cleaned\EEG\W_002\W_002_EEG_ch_Peppa_cleaned_ica_plot.png

# %%
file = "W_000_EEG_cg_Peppa_cleaned.nc"

ncdf_path = os.path.join(cleaned_signals_folder, file[:5], file)

with xr.open_dataarray(ncdf_path) as da:
    print("===== FILE METADATA =====")
    for key, value in da.attrs.items():
        print(f"{key}: {value}")
    print("======================\n")

    signals = da.values.T.copy()  
    time_s = da.coords['time'].values.copy()
    channel_names = da.coords['channel'].values.tolist() 
    
    fs = float(da.attrs['sampling_freq'])
    event_duration_s = float(da.attrs['event_duration_s'])

plot_loaded_eeg_signals(
    time_s=time_s, 
    signals=signals, 
    channel_names=channel_names,
    event_duration_s=event_duration_s,
    title=f"{'_'.join(file.split('_')[1:5])} - Cleaned with ICA"
)
# Out:
# ===== FILE METADATA =====
# dyad_id: W_000
# who: cg
# sampling_freq: 128.0
# event_name: Peppa
# event_start: 0.0
# event_duration: 60.390625
# time_margin_s: 10.0
# channel_names_csv: Fp1,Fp2,F7,F3,Fz,F4,F8,M1,T3,C3,Cz,C4,T4,M2,T5,P3,Pz,P4,T6,O1,O2
# channel_names_json: ["Fp1", "Fp2", "F7", "F3", "Fz", "F4", "F8", "M1", "T3", "C3", "Cz", "C4", "T4", "M2", "T5", "P3", "Pz", "P4", "T6", "O1", "O2"]
# metadata_json: {"notes": NaN, "child_info": {"age_months": 62.0, "group": "TD", "sex": "B"}, "event_order": ["Brave", "Incredibles", "Peppa"], "eeg": {"filtration": {"notch": {"Q": 30, "freq": 50, "a": "[ 1.         -1.89691257  0.9898254 ]", "b": "[ 0.9949127  -1.89691257  0.9949127 ]", "applied": true}, "low_pass": {"type": "fir", "a": 1.0, "b": "[-1.41709605e-04 -1.91445497e-04 -2.32147468e-04 -2.61588048e-04\n -2.77745383e-04 -2.78886553e-04 -2.63684188e-04 -2.31361883e-04\n -1.81857603e-04 -1.15988600e-04 -3.55969706e-05  5.63474871e-05\n  1.55710525e-04  2.57243634e-04  3.54736737e-04  4.41281255e-04\n  5.09641787e-04  5.52723832e-04  5.64113853e-04  5.38657596e-04\n  4.73033980e-04  3.66276007e-04  2.20187851e-04  3.96091832e-05\n -1.67515909e-04 -3.90297400e-04 -6.15302610e-04 -8.27204094e-04\n -1.00965239e-03 -1.14633382e-03 -1.22215458e-03 -1.22447593e-03\n -1.14431349e-03 -9.77406686e-04 -7.25064933e-04 -3.94703910e-04\n  1.04980417e-18  4.39388005e-04  8.98553842e-04  1.34852817e-03\n  1.75787183e-03  2.09460413e-03  2.32836126e-03  2.43265436e-03\n  2.38707761e-03  2.17930753e-03  1.80673506e-03  1.27758441e-03\n  6.11395864e-04 -1.61216890e-04 -9.99581476e-04 -1.85475153e-03\n -2.67200668e-03 -3.39396039e-03 -3.96411891e-03 -4.33069210e-03\n -4.45042484e-03 -4.29219841e-03 -3.84014779e-03 -3.09605284e-03\n -2.08079116e-03 -8.34684995e-04  5.83366595e-04  2.09800925e-03\n  3.62077131e-03  5.05450173e-03  6.29871530e-03  7.25558300e-03\n  7
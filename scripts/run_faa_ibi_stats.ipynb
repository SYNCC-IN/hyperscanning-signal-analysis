# %%
import os
import sys

import importlib
from pathlib import Path

sys.path.insert(0, os.path.abspath('..'))

import src.group_analysis
importlib.reload(src.group_analysis)
from src.group_analysis import load_and_aggregate_data, run_group_analysis

# %%
output_ffDTF_folder = Path(r"C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\RESULTS\ffDTF_4Hz_p5")
target_events = ["Brave", "Peppa", "Incredibles"]

# %%
stacked_by_group, stacked_by_sex, FS, CHANNEL_NAMES = load_and_aggregate_data(output_ffDTF_folder)
# Out:
#  Group: TD              | Film: Brave        | ff_dtf_g         shape: (29, 4, 4, 200)
#  Group: TD              | Film: Brave        | spectra_global   shape: (29, 4, 4, 200)
#  Group: TD              | Film: Brave        | ff_dtf_w         shape: (29, 3, 4, 4, 200)
#  Group: TD              | Film: Brave        | spectra_windowed shape: (29, 3, 4, 4, 200)
#  Group: ASD             | Film: Brave        | ff_dtf_g         shape: (18, 4, 4, 200)
#  Group: ASD             | Film: Brave        | spectra_global   shape: (18, 4, 4, 200)
#  Group: ASD             | Film: Brave        | ff_dtf_w         shape: (18, 3, 4, 4, 200)
#  Group: ASD             | Film: Brave        | spectra_windowed shape: (18, 3, 4, 4, 200)
#  Group: P               | Film: Brave        | ff_dtf_g         shape: (7, 4, 4, 200)
#  Group: P               | Film: Brave        | spectra_global   shape: (7, 4, 4, 200)
#  Group: P               | Film: Brave        | ff_dtf_w         shape: (7, 3, 4, 4, 200)
# ...

# %%
FILMS = ["Brave", "Peppa", "Incredibles"]
cond1, cond2 = "TD", "ASD"
run_group_analysis(stacked_by_group, cond1, cond2, FILMS, CHANNEL_NAMES, FS, output_base_dir=Path(r"C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\RESULTS_group_analysis\groups"))
# Out:
# [INFO] Processing film: Brave
# [INFO] Saved all plots for Brave in C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\RESULTS_group_analysis\groups\Brave_TD_vs_ASD
#
# [INFO] Processing film: Peppa
# [INFO] Saved all plots for Peppa in C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\RESULTS_group_analysis\groups\Peppa_TD_vs_ASD
#
# [INFO] Processing film: Incredibles
# [INFO] Saved all plots for Incredibles in C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\RESULTS_group_analysis\groups\Incredibles_TD_vs_ASD

# %%
cond1, cond2 = "B", "G"
run_group_analysis(stacked_by_sex, cond1, cond2, FILMS, CHANNEL_NAMES, FS, output_base_dir=Path(r"C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\RESULTS_group_analysis\sex"))
# Out:
# [INFO] Processing film: Brave
# [INFO] Saved all plots for Brave in C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\RESULTS_group_analysis\sex\Brave_B_vs_G
#
# [INFO] Processing film: Peppa
# [INFO] Saved all plots for Peppa in C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\RESULTS_group_analysis\sex\Peppa_B_vs_G
#
# [INFO] Processing film: Incredibles
# [INFO] Saved all plots for Incredibles in C:\Users\matit\Studia\Magisterka\SYNCCIN\hyperscanning-signal-analysis\RESULTS_group_analysis\sex\Incredibles_B_vs_G

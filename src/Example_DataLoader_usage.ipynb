# %%
import dataloader


plot_flag = True
# creates a DataLoader class object that creates a structure described in the docs folder (data_structure_spec.md) from raw data
# data = DataLoader(, )
multimodal_data = dataloader.load_eeg_data("W_010", "../data/eeg/", plot_flag)
dataloader.save_to_file(multimodal_data, "../DATA/OUT")

# usage of staticmethod load_output_data loads data created by DataLoader
# out = DataLoader.load_output_data("/Users/admin/PycharmProjects/hyperscanning-signal-analysis/DATA/OUT/W_010.joblib")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 7
#       4 plot_flag = True
#       5 # creates a DataLoader class object that creates a structure described in the docs folder (data_structure_spec.md) from raw data
#       6 # data = DataLoader(, )
# ----> 7 multimodal_data = dataloader.load_eeg_data("W_010", "../data/eeg/", plot_flag)
#       8 dataloader.save_to_file(multimodal_data, "../DATA/OUT")
#      10 # usage of staticmethod load_output_data loads data created by DataLoader
#      11 # out = DataLoader.load_output_data("/Users/admin/PycharmProjects/hyperscanning-signal-analysis/DATA/OUT/W_010.joblib")
#
# File ~/PycharmProjects/ET_eksploracja/hyperscanning-signal-analysis/src/dataloader.py:33, in load_eeg_data(dyad_id, folder_eeg, plot_flag, lowcut, highcut)
#      23 multimodal_data.eeg_channel_names_ch = ['Fp1', 'Fp2', 'F7', 'F3', 'Fz', 'F4', 'F8', 'M1', 'T3', 'C3', 'Cz',
#      24                                         'C4', 'T4',
#      25                                         'M2',
#      26                                         'T5', 'P3', 'Pz', 'P4', 'T6', 'O1', 'O2']
#      27 multimodal_data.eeg_channel_names_cg = ['Fp1_cg', 'Fp2_cg', 'F7_cg', 'F3_cg', 'Fz_cg', 'F4_cg', 'F8_cg',
#      28                                         'M1_cg', 'T3_cg',
#      29                                         'C3_cg', 'Cz_cg', 'C4_cg', 'T4_cg', 'M2_cg', 'T5_cg', 'P3_cg', 'Pz_cg',
#      30                                         'P4_cg',
#      31                                         'T6_cg', 'O1_cg', 'O2_cg']
# ---> 33 raw_eeg_data = _read_raw_svarog_data(multimodal_data, plot_flag)
#      35 # extract diode signal for event detection filtering
#      36 diode = raw_eeg_data[multimodal_data.eeg_channel_mapping['Diode'], :]
#
# File ~/PycharmProjects/ET_eksploracja/hyperscanning-signal-analysis/src/dataloader.py:59, in _read_raw_svarog_data(multimodal_data, plot_flag)
#      57 file = multimodal_data.id + ".obci"  # SVAROG files have .obci extension
#      58 # read meta information from xml file
# ---> 59 with open(os.path.join(multimodal_data.paths.eeg_directory, f"{file}.xml")) as fd:
#      60     xml = xmltodict.parse(fd.read())
#      62 n_channels = int(xml['rs:rawSignal']['rs:channelCount'])
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/eeg/W_010.obci.xml'

# %%
# plot multimodal_data.eeg_data[0, :100]
import matplotlib.pyplot as plt
plt.plot(multimodal_data.eeg_data[35, :])# round(4e5):round(7e5)])
print(multimodal_data.eeg_channel_mapping)
multimodal_data.eeg_data[:, :100]

# %%
multimodal_data.eeg_data_ch()[:, :100]

# %%
multimodal_data.eeg_data_cg()[:, :100]

# %%
from src.DataLoader import DataLoader

plot_flag = True
# creates a DataLoader class object that creates a structure described in the docs folder (data_structure_spec.md) from raw data
data = DataLoader("W_004", plot_flag)
data.set_eeg_data("../data/eeg/")
# data.save_to_file()

# usage of staticmethod load_output_data loads data created by DataLoader
# out = DataLoader.load_output_data("/Users/admin/PycharmProjects/hyperscanning-signal-analysis/DATA/OUT/W_010.joblib")
# Out:
# N_chan: 48,
#  Fs_EEG: 1024,
#  ChanNames: ['Fp1', 'Fp2', 'F7', 'F3', 'Fz', 'F4', 'F8', 'M1', 'T3', 'C3', 'Cz', 'C4', 'T4', 'M2', 'T5', 'P3', 'Pz', 'P4', 'T6', 'O1', 'O2', 'EKG1', 'EKG2', 'Audio', 'Diode', 'Fp1_cg', 'Fp2_cg', 'F7_cg', 'F3_cg', 'Fz_cg', 'F4_cg', 'F8_cg', 'M1_cg', 'T3_cg', 'C3_cg', 'Cz_cg', 'C4_cg', 'T4_cg', 'M2_cg', 'T5_cg', 'P3_cg', 'Pz_cg', 'P4_cg', 'T6_cg', 'O1_cg', 'O2_cg', 'EKG1_cg', 'EKG2_cg']
# Detected events: [{'start': 263.7412109375, 'duration': 59.3310546875, 'name': 'Merida'}, {'start': 333.3056640625, 'duration': 59.6298828125, 'name': 'Peppa'}, {'start': 403.1689453125, 'duration': 59.212890625, 'name': 'Iniemamocni'}, {'start': 603.208984375, 'duration': 181.0556640625, 'name': 'Talk_1'}, {'start': 898.2431640625, 'duration': 181.0546875, 'name': 'Talk_2'}]
# /home/m1kush/Downloads/hyperscanning-signal-analysis/.venv/lib/python3.13/site-packages/IPython/core/events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /home/m1kush/Downloads/hyperscanning-signal-analysis/.venv/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
